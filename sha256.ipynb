# %%
import os
import random
import hashlib

# %%
Plaintext = "Testing SHA256"
shared_secret = "BF17C8E75CA5344F174C3ACE22FE6DC30BE34E81C6420C5618D8182613EE910A"

# %%
def sh256_hash(data: str | bytes) -> str:
    if isinstance(data, str):
        data = data.encode('utf-8')
    return hashlib.sha256(data).hexdigest()

# %%
sh256_hash(shared_secret)
# Out:
# '1a1e35d5baecd4ef289d0ebe91af21e9adbc619527e67478e5c52987ccd9b4a9'

# %%
sh256_hash(shared_secret)
# Out:
# '1a1e35d5baecd4ef289d0ebe91af21e9adbc619527e67478e5c52987ccd9b4a9'
